# %%
import matplotlib.pyplot as plt
import pandas as pd

columns_names = ["title", "price", "currency", "total sold", "condition", "color", "theme", "features", "url"]
df = pd.read_csv ('output.csv', names = columns_names)
final_df = df.iloc[:,[1,3]]
print(final_df)

df.groupby('color')['condition', 'features'].nunique().plot(kind = 'bar').get_figure()
fig.savefig('verticalbarplot.pdf')
# Out:
#      price total sold
# 0    18.00          0
# 1    19.99        499
# 2    16.99        237
# 3    16.99        428
# 4   220.00          0
# ..     ...        ...
# 59    9.95          0
# 60   89.85          0
# 61   29.00          0
# 62   18.99          0
# 63   20.95          0
#
# [64 rows x 2 columns]
# <ipython-input-46-9a11bab400e1>:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby('color')['condition', 'features'].nunique().plot(kind = 'bar').get_figure()
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-46-9a11bab400e1> in <module>
#       8
#       9 df.groupby('color')['condition', 'features'].nunique().plot(kind = 'bar').get_figure()
# ---> 10 fig.savefig('verticalbarplot.pdf')
#
# AttributeError: 'AxesSubplot' object has no attribute 'savefig'

# %%
df.plot(kind='scatter', x = 'total sold', y = 'price', color = 'red')
# Out:
# <AxesSubplot:xlabel='total sold', ylabel='price'>

# %%
df[['price']].plot(kind='hist', bins = [0, 50, 100, 150, 200, 250, 300], rwidth= 0.8)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-49-d914cdcb87b8> in <module>
# ----> 1 df[['price']].plot(kind='hist', bins = [0, 50, 100, 150, 200, 250, 300], rwidth= 0.8)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     953                     data.columns = label_name
#     954
# --> 955         return plot_backend.plot(data, kind=kind, **kwargs)
#     956
#     957     __call__.__doc__ = __doc__
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      59             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      60     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 61     plot_obj.generate()
#      62     plot_obj.draw()
#      63     return plot_obj.result
#
# ...
