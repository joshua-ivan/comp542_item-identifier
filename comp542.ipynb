# %%
import matplotlib.pyplot as plt
import pandas as pd

columns_names = ["title", "price", "currency", "total sold", "condition", "color", "theme", "features", "url"]
df = pd.read_csv ('output.csv', names = columns_names)
final_df = df.iloc[:,[1,3]]
print(final_df)

fig = df.groupby('color')['condition', 'features'].nunique().plot(kind = 'bar').get_figure()
fig.savefig('verticalbarplot.pdf')
# Out:
#      price total sold
# 0    18.00          0
# 1    19.99        499
# 2    16.99        237
# 3    16.99        428
# 4   220.00          0
# ..     ...        ...
# 59    9.95          0
# 60   89.85          0
# 61   29.00          0
# 62   18.99          0
# 63   20.95          0
#
# [64 rows x 2 columns]
# /tmp/ipykernel_6996/256545824.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   fig = df.groupby('color')['condition', 'features'].nunique().plot(kind = 'bar').get_figure()

# %%
df.plot(kind='scatter', x = 'total sold', y = 'price', color = 'red')
# Out:
# <AxesSubplot:xlabel='total sold', ylabel='price'>

# %%
df[['price']].plot(kind='hist', bins = [0, 50, 100, 150, 200, 250, 300], rwidth= 0.8)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_6996/2711393899.py in <module>
# ----> 1 df[['price']].plot(kind='hist', bins = [0, 50, 100, 150, 200, 250, 300], rwidth= 0.8)
#
# ~/comp542/comp542/lib/python3.9/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     970                     data.columns = label_name
#     971
# --> 972         return plot_backend.plot(data, kind=kind, **kwargs)
#     973
#     974     __call__.__doc__ = __doc__
#
# ~/comp542/comp542/lib/python3.9/site-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      69             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71     plot_obj.generate()
#      72     plot_obj.draw()
#      73     return plot_obj.result
#
# ~/comp542/comp542/lib/python3.9/site-packages/pandas/plotting/_matplotlib/core.py in generate(self)
#     284     def generate(self):
#     285         self._args_adjust()
# --> 286         self._compute_plot_data()
#     287         self._setup_subplots()
#     288         self._make_plot()
#
# ~/comp542/comp542/lib/python3.9/site-packages/pandas/plotting/_matplotlib/core.py in _compute_plot_data(self)
#     451         # no non-numeric frames or series allowed
#     452         if is_empty:
# --> 453             raise TypeError("no numeric data to plot")
#     454
#     455         self.data = numeric_data.apply(self._convert_to_ndarray)
#
# TypeError: no numeric data to plot

# %%
import numpy as np

tag_frame = df.iloc[:,[6,7]]
tag_frame = tag_frame.fillna(value='')
tag_frame['tags'] = tag_frame['theme'].str.split(', ') + tag_frame['features'].str.split(', ')
tag_frame['tags'] = [[i for i in list_ if i not in ['']] for list_ in tag_frame['tags']]
tag_flat_list = np.concatenate(tag_frame['tags'].to_numpy())
tag_frequency = pd.value_counts(tag_flat_list)

most_freqent_tags = tag_freqency[tag_freqency > 4]
tag_chart = most_frequent_tags.plot.pie(label='Count')
print(most_frequent_tags)
# Out:
# 90s            30
# All Seasons    17
# 80s            13
# Breathable      9
# Rock            8
# Movie           6
# Retro           6
# Easy Care       6
# 70s             6
# Music           5
# Band            5
# dtype: int64
